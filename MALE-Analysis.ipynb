# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
file_path = 'loan_sanction_test.csv'

# %%
df = pd.read_csv(file_path)

# %% [markdown]
# ** - - - - - 1 - MALE  - - - - - **

# %%
Male = df['Gender']

# %%
df_married_males = df[(df['Gender'] == 'Male') & (df['Married'] == 'Yes')]

# %%
print(df_married_males)
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 5    LP001054   Male     Yes          0  Not Graduate           Yes
# ..        ...    ...     ...        ...           ...           ...
# 358  LP002954   Male     Yes          2  Not Graduate            No
# 361  LP002969   Male     Yes          1      Graduate            No
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
df_married_males = df[(df['Gender'] == 'Male') & (df['Married'] == 'Yes') & (df['Education'] == 'Graduate')]

# %%
mode_df_married_males = df_married_males.mode()

# %%
print(mode_df_married_males)
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 0    LP001015   Male     Yes          0  Graduate            No
# 1    LP001022    NaN     NaN        NaN       NaN           NaN
# 2    LP001031    NaN     NaN        NaN       NaN           NaN
# 3    LP001035    NaN     NaN        NaN       NaN           NaN
# 4    LP001059    NaN     NaN        NaN       NaN           NaN
# ..        ...    ...     ...        ...       ...           ...
# 149  LP002932    NaN     NaN        NaN       NaN           NaN
# 150  LP002935    NaN     NaN        NaN       NaN           NaN
# 151  LP002969    NaN     NaN        NaN       NaN           NaN
# 152  LP002975    NaN     NaN        NaN       NaN           NaN
# 153  LP002986    NaN     NaN        NaN       NaN           NaN
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5000.0                0.0       100.0             360.0
# ...

# %%
mean_df_married_males = df_married_males['ApplicantIncome'].mean()

# %%
print(mean_df_married_males)
# Out:
# 5555.662337662337

# %%
df_married_males_NotGraduate = df[(df['Gender'] == 'Male') & (df['Married'] == 'Yes') & (df['Education'] == 'Not Graduate')]
print(df_married_males)
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 5    LP001054   Male     Yes          0  Not Graduate           Yes
# 7    LP001056   Male     Yes          2  Not Graduate            No
# 20   LP001121   Male     Yes          1  Not Graduate            No
# 42   LP001226   Male     Yes          0  Not Graduate            No
# 46   LP001237   Male     Yes        NaN  Not Graduate            No
# 49   LP001270   Male     Yes         3+  Not Graduate           Yes
# 54   LP001312   Male     Yes          0  Not Graduate           Yes
# 60   LP001332   Male     Yes          0  Not Graduate            No
# 64   LP001348   Male     Yes         3+  Not Graduate            No
# 66   LP001352   Male     Yes          0  Not Graduate            No
# 74   LP001386   Male     Yes          0  Not Graduate            No
# 82   LP001445   Male     Yes          2  Not Graduate            No
# 93   LP001490   Male     Yes          2  Not Graduate            No
# ...

# %%
mean_NotGraduate_married_males = df_married_males_NotGraduate['ApplicantIncome'].mean()
print(mean_NotGraduate_married_males)
# Out:
# 3888.38

# %%
married_males_perArea = df[(df['Gender'] == 'Male') & (df['Married'] == 'Yes')]
married_males_perArea = df['Property_Area'].value_counts()

# %%
print(married_males_perArea)
# Out:
# Property_Area
# Urban        140
# Semiurban    116
# Rural        111
# Name: count, dtype: int64

# %% [markdown]
# ** 1.1 - - - - - - SINGLE MALES - - - - - - **

# %%
single_males = df[(df['Gender'] == 'Male') & (df['Married'] == 'No')]
print(single_males)
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 4    LP001051   Male      No          0  Not Graduate            No
# 9    LP001067   Male      No          0  Not Graduate            No
# 10   LP001078   Male      No          0  Not Graduate            No
# 12   LP001083   Male      No         3+      Graduate            No
# 15   LP001099   Male      No          1      Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 351  LP002901   Male      No          0      Graduate            No
# 357  LP002952   Male      No          0      Graduate            No
# 359  LP002962   Male      No          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 4               3276                  0        78.0             360.0
# ...

# %%
single_males_Graduates = df[(df['Education'] == 'Graduate')]
single_males_Graduates = df['ApplicantIncome'].median()
print(single_males_Graduates)
# Out:
# 3786.0

# %%
single_males_NoGraduates = df[(df['Education'] == 'Not Graduate')]
single_males_NoGraduates = df['ApplicantIncome'].median()
print(single_males_NoGraduates)
# Out:
# 3786.0

# %%
single_males = df['Property_Area'].value_counts()
print(single_males)
# Out:
# Property_Area
# Urban        140
# Semiurban    116
# Rural        111
# Name: count, dtype: int64
